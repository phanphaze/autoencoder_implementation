# %%
# Paths
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

# %%
# Imports
from src.train import train_model
from src.utils import plot_loss_curve, evaluate_and_plot

# %%
# Preprocess
from src.preprocess import setup_data
setup_data()

# %%
# Train model
train_losses, val_losses = train_model()
# Out:
# Model: Autoencoder with CNN
# Training on device: cpu
# Epoch 0 | Train Loss: 0.3472 | Val Loss: 0.2398
# Epoch 1 | Train Loss: 0.2042 | Val Loss: 0.1747
# Epoch 2 | Train Loss: 0.1592 | Val Loss: 0.1456
# Epoch 3 | Train Loss: 0.1385 | Val Loss: 0.1313
# Epoch 4 | Train Loss: 0.1283 | Val Loss: 0.1243
# Epoch 5 | Train Loss: 0.1230 | Val Loss: 0.1202
# Epoch 6 | Train Loss: 0.1201 | Val Loss: 0.1183
# Epoch 7 | Train Loss: 0.1184 | Val Loss: 0.1170
# Epoch 8 | Train Loss: 0.1174 | Val Loss: 0.1163
# Early stopping triggered at epoch 8 due to validation stagnation.
# Model saved to: C:\Users\caden\CompSci\autoencoder_implementation\models\conv_autoencoder_4.pth

# %%
# Plot the loss curve
plot_loss_curve(train_losses, val_losses)

# %%
# Display original vs reconstructed images
evaluate_and_plot(architecture="conv")
# Out:
# Successfully loaded conv_autoencoder_4.pth
