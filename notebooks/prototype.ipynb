# %%
# Paths
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

# %%
# Imports
from src.train import train_model
from src.utils import plot_loss_curve, evaluate_and_plot

# %%
# Preprocess
from src.preprocess import setup_data
setup_data()

# %%
# Train model
losses = train_model(architecture="conv", patience=5)
# Out:
# Model: Autoencoder with CNN
# Training on device: cpu
# Epoch 0, Average Loss: 0.3895
# Epoch 1, Average Loss: 0.1964
# Epoch 2, Average Loss: 0.1452
# Epoch 3, Average Loss: 0.1276
# Epoch 4, Average Loss: 0.1209
# Epoch 5, Average Loss: 0.1181
# Epoch 6, Average Loss: 0.1168
# Epoch 7, Average Loss: 0.1162
# Epoch 8, Average Loss: 0.1159
# Epoch 9, Average Loss: 0.1157
# Epoch 10, Average Loss: 0.1156
# Epoch 11, Average Loss: 0.1155
# Early stopping triggered at epoch 11 due to stagnation.
# Model saved to: C:\Users\caden\CompSci\autoencoder_implementation\models\conv_autoencoder_3.pth

# %%
# Plot the loss curve
plot_loss_curve(losses)
# add train & test validation curves

# %%
# Display original vs reconstructed images
evaluate_and_plot(architecture="conv")
# Out:
# Successfully loaded conv_autoencoder_3.pth
